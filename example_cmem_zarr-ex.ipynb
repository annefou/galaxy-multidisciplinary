# %% [markdown]
# # Global Copernicus Marine example

# %%
import xarray as xr

# %% [markdown]
# ## Time chunked

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-time-015/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy_anfc_merged-uv_PT1H-i_202211/timeChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 9TB
# Dimensions:    (elevation: 1, latitude: 2041, longitude: 4320, time: 33384)
# Coordinates:
#   * elevation  (elevation) float32 4B -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 267kB 2020-11-01 ... 2024-08-22T23:00:00
# Data variables:
#     uo         (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
#     utide      (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
#     utotal     (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
#     vo         (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
# ...

# %% [markdown]
# ## Geo chunked

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-geo-015/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy_anfc_merged-uv_PT1H-i_202211/geoChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 9TB
# Dimensions:    (elevation: 1, latitude: 2041, longitude: 4320, time: 33384)
# Coordinates:
#   * elevation  (elevation) float32 4B -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 267kB 2020-11-01 ... 2024-08-22T23:00:00
# Data variables:
#     uo         (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(4272, 1, 16, 8), meta=np.ndarray>
#     utide      (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(4272, 1, 16, 8), meta=np.ndarray>
#     utotal     (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(4272, 1, 16, 8), meta=np.ndarray>
#     vo         (time, elevation, latitude, longitude) float32 1TB dask.array<chunksize=(4272, 1, 16, 8), meta=np.ndarray>
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-time-013/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy-thetao_anfc_0.083deg_PT6H-i_202406/timeChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 6TB
# Dimensions:    (elevation: 50, latitude: 2041, longitude: 4320, time: 3257)
# Coordinates:
#   * elevation  (elevation) float32 200B -5.728e+03 -5.275e+03 ... -1.541 -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 26kB 2022-06-01 ... 2024-08-23
# Data variables:
#     thetao     (time, elevation, latitude, longitude) float32 6TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     institution:                   Mercator Ocean
#     licence:                       http://marine.copernicus.eu/services-portf...
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-geo-013/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy-thetao_anfc_0.083deg_PT6H-i_202406/geoChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 6TB
# Dimensions:    (elevation: 50, latitude: 2041, longitude: 4320, time: 3257)
# Coordinates:
#   * elevation  (elevation) float32 200B -5.728e+03 -5.275e+03 ... -1.541 -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 26kB 2022-06-01 ... 2024-08-23
# Data variables:
#     thetao     (time, elevation, latitude, longitude) float32 6TB dask.array<chunksize=(526, 1, 32, 32), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     institution:                   Mercator Ocean
#     licence:                       http://marine.copernicus.eu/services-portf...
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-time-010/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy-so_anfc_0.083deg_PT6H-i_202406/timeChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 6TB
# Dimensions:    (elevation: 50, latitude: 2041, longitude: 4320, time: 3257)
# Coordinates:
#   * elevation  (elevation) float32 200B -5.728e+03 -5.275e+03 ... -1.541 -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 26kB 2022-06-01 ... 2024-08-23
# Data variables:
#     so         (time, elevation, latitude, longitude) float32 6TB dask.array<chunksize=(1, 1, 512, 2048), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     institution:                   Mercator Ocean
#     licence:                       http://marine.copernicus.eu/services-portf...
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-geo-010/arco/GLOBAL_ANALYSISFORECAST_PHY_001_024/cmems_mod_glo_phy-so_anfc_0.083deg_PT6H-i_202406/geoChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 6TB
# Dimensions:    (elevation: 50, latitude: 2041, longitude: 4320, time: 3257)
# Coordinates:
#   * elevation  (elevation) float32 200B -5.728e+03 -5.275e+03 ... -1.541 -0.494
#   * latitude   (latitude) float32 8kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 17kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 26kB 2022-06-01 ... 2024-08-23
# Data variables:
#     so         (time, elevation, latitude, longitude) float32 6TB dask.array<chunksize=(526, 1, 32, 32), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     institution:                   Mercator Ocean
#     licence:                       http://marine.copernicus.eu/services-portf...
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-time-015/arco/GLOBAL_ANALYSISFORECAST_WAV_001_027/cmems_mod_glo_wav_anfc_0.083deg_PT3H-i_202311/timeChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 11TB
# Dimensions:    (time: 8456, latitude: 2041, longitude: 4320)
# Coordinates:
#   * latitude   (latitude) float64 16kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float64 35kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 68kB 2021-10-01T03:00:00 ... 2024-08-23
# Data variables: (12/18)
#     VCMX       (time, latitude, longitude) float64 596GB dask.array<chunksize=(1, 512, 2048), meta=np.ndarray>
#     VHM0       (time, latitude, longitude) float64 596GB dask.array<chunksize=(1, 512, 2048), meta=np.ndarray>
#     VHM0_SW1   (time, latitude, longitude) float64 596GB dask.array<chunksize=(1, 512, 2048), meta=np.ndarray>
#     VHM0_SW2   (time, latitude, longitude) float64 596GB dask.array<chunksize=(1, 512, 2048), meta=np.ndarray>
#     VHM0_WW    (time, latitude, longitude) float64 596GB dask.array<chunksize=(1, 512, 2048), meta=np.ndarray>
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-geo-015/arco/GLOBAL_ANALYSISFORECAST_WAV_001_027/cmems_mod_glo_wav_anfc_0.083deg_PT3H-i_202311/geoChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 11TB
# Dimensions:    (time: 8456, latitude: 2041, longitude: 4320)
# Coordinates:
#   * latitude   (latitude) float64 16kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float64 35kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 68kB 2021-10-01T03:00:00 ... 2024-08-23
# Data variables: (12/18)
#     VCMX       (time, latitude, longitude) float64 596GB dask.array<chunksize=(1184, 16, 32), meta=np.ndarray>
#     VHM0       (time, latitude, longitude) float64 596GB dask.array<chunksize=(1184, 16, 32), meta=np.ndarray>
#     VHM0_SW1   (time, latitude, longitude) float64 596GB dask.array<chunksize=(1184, 16, 32), meta=np.ndarray>
#     VHM0_SW2   (time, latitude, longitude) float64 596GB dask.array<chunksize=(1184, 16, 32), meta=np.ndarray>
#     VHM0_WW    (time, latitude, longitude) float64 596GB dask.array<chunksize=(1184, 16, 32), meta=np.ndarray>
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-time-050/arco/WIND_GLO_PHY_L4_NRT_012_004/cmems_obs-wind_glo_phy_nrt_l4_0.125deg_PT1H_202207/timeChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 31TB
# Dimensions:                         (time: 36096, latitude: 1440,
#                                      longitude: 2880)
# Coordinates:
#   * latitude                        (latitude) float32 6kB -89.94 ... 89.94
#   * longitude                       (longitude) float32 12kB -179.9 ... 179.9
#   * time                            (time) datetime64[ns] 289kB 2020-07-01 .....
# Data variables: (12/27)
#     air_density                     (time, latitude, longitude) float64 1TB dask.array<chunksize=(1, 512, 1024), meta=np.ndarray>
#     eastward_stress                 (time, latitude, longitude) float64 1TB dask.array<chunksize=(1, 512, 1024), meta=np.ndarray>
#     eastward_stress_bias            (time, latitude, longitude) float64 1TB dask.array<chunksize=(1, 512, 1024), meta=np.ndarray>
#     eastward_stress_sdd             (time, latitude, longitude) float64 1TB dask.array<chunksize=(1, 512, 1024), meta=np.ndarray>
# ...

# %%
uri = "https://s3.waw3-1.cloudferro.com/mdl-arco-geo-050/arco/WIND_GLO_PHY_L4_NRT_012_004/cmems_obs-wind_glo_phy_nrt_l4_0.125deg_PT1H_202207/geoChunked.zarr"

# %%
dset = xr.open_zarr(uri)
dset
# Out:
# <xarray.Dataset> Size: 31TB
# Dimensions:                         (time: 36096, latitude: 1440,
#                                      longitude: 2880)
# Coordinates:
#   * latitude                        (latitude) float32 6kB -89.94 ... 89.94
#   * longitude                       (longitude) float32 12kB -179.9 ... 179.9
#   * time                            (time) datetime64[ns] 289kB 2020-07-01 .....
# Data variables: (12/27)
#     air_density                     (time, latitude, longitude) float64 1TB dask.array<chunksize=(4948, 8, 8), meta=np.ndarray>
#     eastward_stress                 (time, latitude, longitude) float64 1TB dask.array<chunksize=(4948, 8, 8), meta=np.ndarray>
#     eastward_stress_bias            (time, latitude, longitude) float64 1TB dask.array<chunksize=(4948, 8, 8), meta=np.ndarray>
#     eastward_stress_sdd             (time, latitude, longitude) float64 1TB dask.array<chunksize=(4948, 8, 8), meta=np.ndarray>
# ...
